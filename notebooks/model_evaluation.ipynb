# %% [markdown]
# # Model Evaluation & Pipeline Test
# Let's test the entire pipeline (MobileNetV2 -> YOLOv8) on a sample frame.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.model.evaluate import evaluate_model
from src.detection.image_detection import ImageDetector
import matplotlib.pyplot as plt
import cv2

# %%
# Evaluate on test fold
evaluate_model()

# %%
# Test Pipeline
detector = ImageDetector()
# Ensure you have a sample image at this path
sample_img = '../data/raw/test/fire/sample.jpg'

if os.path.exists(sample_img):
    img, has_fire, detections = detector.detect(sample_img)
    
    print(f"Fire Detected: {has_fire}")
    print(f"YOLO Detections: {len(detections)}")
    
    plt.figure(figsize=(10,10))
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()
else:
    print(f"{sample_img} does not exist. Please place an image there to test.")
