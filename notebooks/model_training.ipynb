# %% [markdown]
# # Model Training: MobileNetV2
# Here we will import our core logic and train the binary classifier.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.model.train import train_model

# %%
# Execute the training pipeline
train_model()
